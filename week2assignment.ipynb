# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.krackhardt_kite_graph(create_using=None)

# %%
pos = nx.spring_layout(G)
labels = {
    0: "Andre",
    1: "Beverly", 
    2: "Carol", 
    3: "Diane", 
    4: "Ed", 
    5: "Fernando", 
    6: "Garth", 
    7: "Heather", 
    8: "Ike", 
    9: "Jane"
}

# %%
nx.draw_networkx_nodes(G, pos) 
nx.draw_networkx_edges(G, pos) 
nx.draw_networkx_labels(G, pos, labels, font_size=16)
# Out:
# {0: Text(-0.3214581551045309, 0.3595777925724157, 'Andre'),
#  1: Text(-0.03667821336266114, 0.48522926165917957, 'Beverly'),
#  2: Text(-0.43357316458779444, 0.1681770088702582, 'Carol'),
#  3: Text(-0.12237147366519684, 0.29354602141151076, 'Diane'),
#  4: Text(0.17746413450079562, 0.43415196478568974, 'Ed'),
#  5: Text(-0.1637188169034596, 0.03966327943383127, 'Fernando'),
#  6: Text(0.0901259706519879, 0.15173636560481452, 'Garth'),
#  7: Text(0.11219597371518258, -0.2580111429967051, 'Heather'),
#  8: Text(0.2826995489419776, -0.6740705513409948, 'Ike'),
#  9: Text(0.41531419581369944, -0.9999999999999999, 'Jane')}
